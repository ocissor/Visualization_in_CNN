# %%
# %matplotlib inline
import glob
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import imageio as im
from keras import models
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import Dropout
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint

# %%
images=[]
for i in glob.glob("shapes/circles/*.png"):
    images.append(mpimg.imread(i))
plt.figure(figsize=(20,10))
columns=5
for i ,image in enumerate(images):
    plt.subplot(len(images) / columns + 1, columns, i+1)
    plt.imshow(image)

# %%
images=[]
for i in glob.glob("shapes/squares/*.png"):
    images.append(mpimg.imread(i))
plt.figure(figsize=(20,10))
columns=5
for i ,image in enumerate(images):
    plt.subplot(len(images) / columns + 1, columns, i+1)
    plt.imshow(image)

# %%
images=[]
for i in glob.glob("shapes/triangles/*.png"):
    images.append(mpimg.imread(i))
plt.figure(figsize=(20,10))
columns=5
for i ,image in enumerate(images):
    plt.subplot(len(images) / columns + 1, columns, i+1)
    plt.imshow(image)

# %%
classifier=Sequential()

# %%
classifier.add(Conv2D(32, (3, 3), padding='same', input_shape = (28, 28, 3), activation = 'relu'))
classifier.add(Conv2D(32, (3, 3), activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2, 2)))
classifier.add(Dropout(0.5)) # antes era 0.25

# Adding a second convolutional layer
classifier.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
classifier.add(Conv2D(64, (3, 3), activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2, 2)))
classifier.add(Dropout(0.5)) # antes era 0.25

# Adding a third convolutional layer
classifier.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
classifier.add(Conv2D(64, (3, 3), activation='relu'))
classifier.add(MaxPooling2D(pool_size=(2, 2)))
classifier.add(Dropout(0.5)) # antes era 0.25

# Step 3 - Flattening
classifier.add(Flatten())

# Step 4 - Full connection
classifier.add(Dense(units = 512, activation = 'relu'))
classifier.add(Dropout(0.5)) 
classifier.add(Dense(units = 3, activation = 'softmax'))

# %%
classifier.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 28, 28, 32)        896
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 26, 26, 32)        9248
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 5, 5, 64)          36928
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 3, 3, 64)          36928
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 1, 1, 64)          0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 1, 1, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               33280
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 174,243
# Trainable params: 174,243
# Non-trainable params: 0
# _________________________________________________________________

# %%
classifier.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
train_datagen=ImageDataGenerator(rescale=1./255)
test_datagen=ImageDataGenerator(rescale=1./255)

training_set = train_datagen.flow_from_directory('shapes_train',
                                                 target_size = (28, 28),
                                                 batch_size = 16,
                                                 class_mode = 'categorical')

testing_set = test_datagen.flow_from_directory('shapes_test',
                                                 target_size = (28, 28),
                                                 batch_size = 16,
                                                 class_mode = 'categorical')
# Out:
# Found 240 images belonging to 3 classes.
# Found 60 images belonging to 3 classes.

# %%
checkpointer=ModelCheckpoint(filepath="best_weights.hdf5",monitor='val_acc',verbose=1,save_best_only=True)

# %%
history = classifier.fit_generator(training_set,
                                   steps_per_epoch = 100,
                                   epochs = 20,
                                   callbacks=[checkpointer],
                                   validation_data = testing_set,
                                   validation_steps = 50)
# Out:
# Epoch 1/20
# 100/100 [==============================] - 9s 88ms/step - loss: 1.1117 - acc: 0.3113 - val_loss: 1.0986 - val_acc: 0.3351
#
# Epoch 00001: val_acc improved from -inf to 0.33511, saving model to best_weights.hdf5
# Epoch 2/20
# 100/100 [==============================] - 6s 56ms/step - loss: 1.1007 - acc: 0.3131 - val_loss: 1.0991 - val_acc: 0.3302
#
# Epoch 00002: val_acc did not improve from 0.33511
# Epoch 3/20
# 100/100 [==============================] - 6s 58ms/step - loss: 1.1007 - acc: 0.3513 - val_loss: 1.0987 - val_acc: 0.3378
#
# Epoch 00003: val_acc improved from 0.33511 to 0.33777, saving model to best_weights.hdf5
# Epoch 4/20
# 100/100 [==============================] - 6s 56ms/step - loss: 1.1042 - acc: 0.3281 - val_loss: 1.0984 - val_acc: 0.3342
#
# Epoch 00004: val_acc did not improve from 0.33777
# Epoch 5/20
# 100/100 [==============================] - 6s 57ms/step - loss: 1.0958 - acc: 0.3469 - val_loss: 1.0155 - val_acc: 0.5505
#
# Epoch 00005: val_acc improved from 0.33777 to 0.55053, saving model to best_weights.hdf5
# Epoch 6/20
# 100/100 [==============================] - 6s 57ms/step - loss: 0.7357 - acc: 0.7188 - val_loss: 0.7765 - val_acc: 0.7152
#
# Epoch 00006: val_acc improved from 0.55053 to 0.71524, saving model to best_weights.hdf5
# Epoch 7/20
# 100/100 [==============================] - 6s 58ms/step - loss: 0.5092 - acc: 0.8113 - val_loss: 0.2676 - val_acc: 0.8830
#
# Epoch 00007: val_acc improved from 0.71524 to 0.88298, saving model to best_weights.hdf5
# Epoch 8/20
# 100/100 [==============================] - 6s 58ms/step - loss: 0.3602 - acc: 0.8631 - val_loss: 0.2753 - val_acc: 0.8837
#
# Epoch 00008: val_acc improved from 0.88298 to 0.88369, saving model to best_weights.hdf5
# Epoch 9/20
# 100/100 [==============================] - 6s 56ms/step - loss: 0.3203 - acc: 0.8812 - val_loss: 0.2273 - val_acc: 0.9176
#
# Epoch 00009: val_acc improved from 0.88369 to 0.91755, saving model to best_weights.hdf5
# Epoch 10/20
# 100/100 [==============================] - 6s 56ms/step - loss: 0.2603 - acc: 0.9056 - val_loss: 0.1488 - val_acc: 0.9332
#
# Epoch 00010: val_acc improved from 0.91755 to 0.93316, saving model to best_weights.hdf5
# Epoch 11/20
# 100/100 [==============================] - 6s 56ms/step - loss: 0.2217 - acc: 0.9200 - val_loss: 0.2082 - val_acc: 0.8976
#
# Epoch 00011: val_acc did not improve from 0.93316
# Epoch 12/20
# 100/100 [==============================] - 6s 59ms/step - loss: 0.1763 - acc: 0.9469 - val_loss: 0.2700 - val_acc: 0.9011
#
# Epoch 00012: val_acc did not improve from 0.93316
# Epoch 13/20
# 100/100 [==============================] - 6s 56ms/step - loss: 0.1393 - acc: 0.9581 - val_loss: 0.2686 - val_acc: 0.8989
#
# Epoch 00013: val_acc did not improve from 0.93316
# Epoch 14/20
# 100/100 [==============================] - 6s 56ms/step - loss: 0.1495 - acc: 0.9525 - val_loss: 0.0923 - val_acc: 0.9666
#
# Epoch 00014: val_acc improved from 0.93316 to 0.96658, saving model to best_weights.hdf5
# Epoch 15/20
# 100/100 [==============================] - 6s 57ms/step - loss: 0.1037 - acc: 0.9700 - val_loss: 0.0226 - val_acc: 1.0000
#
# Epoch 00015: val_acc improved from 0.96658 to 1.00000, saving model to best_weights.hdf5
# Epoch 16/20
# 100/100 [==============================] - 6s 58ms/step - loss: 0.0982 - acc: 0.9706 - val_loss: 0.0291 - val_acc: 0.9840
#
# Epoch 00016: val_acc did not improve from 1.00000
# Epoch 17/20
# 100/100 [==============================] - 5s 55ms/step - loss: 0.0694 - acc: 0.9819 - val_loss: 0.1756 - val_acc: 0.9654
#
# Epoch 00017: val_acc did not improve from 1.00000
# Epoch 18/20
# 100/100 [==============================] - 6s 58ms/step - loss: 0.1142 - acc: 0.9712 - val_loss: 0.0860 - val_acc: 0.9679
#
# Epoch 00018: val_acc did not improve from 1.00000
# Epoch 19/20
# 100/100 [==============================] - 6s 57ms/step - loss: 0.0720 - acc: 0.9800 - val_loss: 0.0735 - val_acc: 0.9668
#
# Epoch 00019: val_acc did not improve from 1.00000
# Epoch 20/20
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0560 - acc: 0.9869 - val_loss: 0.0259 - val_acc: 1.0000
#
# Epoch 00020: val_acc did not improve from 1.00000

# %%
classifier.load_weights('best_weights.hdf5')

# %%
classifier.save('shapes_cnn.h5')

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
img_path = 'shapes/triangles/football.png'

img = image.load_img(img_path, target_size=(28, 28))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor /= 255.

plt.imshow(img_tensor[0])
plt.show()

print(img_tensor.shape)
# Out:
# (1, 28, 28, 3)

# %%
x=image.img_to_array(img)
x=np.expand_dims(x, axis=0)#without expanding the dimension our x would be (28,28,3) but it should be (1,28,28,3) 
x.shape
# Out:
# (1, 28, 28, 3)

# %%
images=np.vstack([x])#it is necessary to stack so that our input is acceptable by our neural net
classes = classifier.predict_classes(images)
print("Predicted class is:",classes)
# Out:
# Predicted class is: [2]

# %%
layer_outputs = [layer.output for layer in classifier.layers[:12]] # Extracts the outputs of the top 12 layers
activation_model = models.Model(inputs=classifier.input, outputs=layer_outputs) # Creates a model that will return these outputs, given the model input

# %%
activations = activation_model.predict(img_tensor) # Returns a list of five Numpy arrays: one array per layer activation

# %%
first_layer_activation = activations[0]
print(first_layer_activation.shape)
# Out:
# (1, 28, 28, 32)

# %%
plt.matshow(first_layer_activation[0, :, :, 4],cmap='viridis')

# %%
layer_names = []
for layer in classifier.layers[:12]:
    layer_names.append(layer.name) # Names of the layers, so you can have them as part of your plot
    
images_per_row = 16

for layer_name, layer_activation in zip(layer_names, activations): # Displays the feature maps
    n_features = layer_activation.shape[-1] # Number of features in the feature map
    size = layer_activation.shape[1] #The feature map has shape (1, size, size, n_features).
    n_cols = n_features // images_per_row # Tiles the activation channels in this matrix
    display_grid = np.zeros((size * n_cols, images_per_row * size))
    for col in range(n_cols): # Tiles each filter into a big horizontal grid
        for row in range(images_per_row):
            channel_image = layer_activation[0,
                                             :, :,
                                             col * images_per_row + row]
            channel_image -= channel_image.mean() # Post-processes the feature to make it visually palatable
            channel_image /= channel_image.std()
            channel_image *= 64
            channel_image += 128
            channel_image = np.clip(channel_image, 0, 255).astype('uint8')
            display_grid[col * size : (col + 1) * size, # Displays the grid
                         row * size : (row + 1) * size] = channel_image
    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1],
                        scale * display_grid.shape[0]))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='viridis')
